# %% [markdown]
# ## RCL (using PyBLP)

# %%
import pandas as pd
import numpy as np
import pyblp

# %% [markdown]
# ### Data Preparation

# %%
df = pd.read_csv('../data/Data.csv', 
                 names=['market_id', 'product_id', 'product_ms',
                        'product_att1', 'product_att2', 'product_att3',
                        'price', 'cost_att1', 'cost_att2', 'cost_att3', 'group'])

# %%
df = df.join(
    df.groupby('market_id')[['product_ms']]
        .transform('sum')  # Calculate the mean for each group
        .rename(columns='sum_ms'.format)  # Rename columns 
)

# %%
df['og_ms'] = 1 - df['sum_ms'] # generate OG market share

# %%
df['delta'] = np.log(df['product_ms']/df['og_ms'])  # generate delta

# %% [markdown]
# ### PyBLP

# %%
df["supply_instruments3"] = np.square(df["product_att1"])
df["supply_instruments4"] = np.square(df["product_att2"])
df["supply_instruments5"] = np.square(df["product_att3"])
df["demand_instruments3"] = np.square(df["cost_att1"])
df["demand_instruments4"] = np.square(df["cost_att2"])
df["demand_instruments5"] = np.square(df["cost_att3"])

# %%
df.rename(columns = {'market_id':'market_ids', 
                     'product_id':'product_ids', 
                     'product_ms':'shares', 
                     'price':'prices', 
                     'cost_att1':'demand_instruments0', 
                     'cost_att2':'demand_instruments1', 
                     'cost_att3':'demand_instruments2',
                     
                    }, inplace = True)

# %%
df["firm_ids"] = df["product_ids"]

# %%
X1_formulation = pyblp.Formulation('1 + prices + product_att1 + product_att2 + product_att3')
X2_formulation = pyblp.Formulation('0 + prices + product_att1 + product_att2 + product_att3')
product_formulations = (X1_formulation, X2_formulation)
product_formulations
# Out:
# (1 + prices + product_att1 + product_att2 + product_att3,
#  prices + product_att1 + product_att2 + product_att3)

# %%
mc_integration = pyblp.Integration('monte_carlo', size=5000, specification_options={'seed': 0})
mc_integration
# Out:
# Configured to construct nodes and weights with Monte Carlo simulation with options {seed: 0}.

# %%
pr_integration = pyblp.Integration('product', size=5)
pr_integration
# Out:
# Configured to construct nodes and weights according to the level-5 Gauss-Hermite product rule with options {}.

# %%
mc_problem = pyblp.Problem(product_formulations, df, integration=mc_integration)
mc_problem
# Out:
# Initializing the problem ...
# Initialized the problem after 00:00:00.
#
# Dimensions:
# =======================================
#  T    N    F     I      K1    K2    MD
# ---  ---  ---  ------  ----  ----  ----
# 50   970  25   250000   5     4     10
# =======================================
#
# Formulations:
# =============================================================================================
#        Column Indices:           0          1             2             3             4
# -----------------------------  ------  ------------  ------------  ------------  ------------
#  X1: Linear Characteristics      1        prices     product_att1  product_att2  product_att3
# X2: Nonlinear Characteristics  prices  product_att1  product_att2  product_att3
# =============================================================================================
# Dimensions:
# =======================================
#  T    N    F     I      K1    K2    MD
# ---  ---  ---  ------  ----  ----  ----
# 50   970  25   250000   5     4     10
# =======================================
#
# Formulations:
# =============================================================================================
#        Column Indices:           0          1             2             3             4
# -----------------------------  ------  ------------  ------------  ------------  ------------
#  X1: Linear Characteristics      1        prices     product_att1  product_att2  product_att3
# X2: Nonlinear Characteristics  prices  product_att1  product_att2  product_att3
# =============================================================================================

# %%
pr_problem = pyblp.Problem(product_formulations, df, integration=pr_integration)
pr_problem
# Out:
# Initializing the problem ...
# Initialized the problem after 00:00:00.
#
# Dimensions:
# ======================================
#  T    N    F     I     K1    K2    MD
# ---  ---  ---  -----  ----  ----  ----
# 50   970  25   31250   5     4     10
# ======================================
#
# Formulations:
# =============================================================================================
#        Column Indices:           0          1             2             3             4
# -----------------------------  ------  ------------  ------------  ------------  ------------
#  X1: Linear Characteristics      1        prices     product_att1  product_att2  product_att3
# X2: Nonlinear Characteristics  prices  product_att1  product_att2  product_att3
# =============================================================================================
# Dimensions:
# ======================================
#  T    N    F     I     K1    K2    MD
# ---  ---  ---  -----  ----  ----  ----
# 50   970  25   31250   5     4     10
# ======================================
#
# Formulations:
# =============================================================================================
#        Column Indices:           0          1             2             3             4
# -----------------------------  ------  ------------  ------------  ------------  ------------
#  X1: Linear Characteristics      1        prices     product_att1  product_att2  product_att3
# X2: Nonlinear Characteristics  prices  product_att1  product_att2  product_att3
# =============================================================================================

# %%
bfgs = pyblp.Optimization('bfgs', {'gtol': 1e-10})

# %%
bfgs
# Out:
# Configured to optimize using the BFGS algorithm implemented in SciPy with analytic gradients and options {gtol: +1.000000E-10}.

# %%
results1 = mc_problem.solve(sigma=np.ones((4, 4)), optimization=bfgs)
results1
# Out:
# Solving the problem ...
#
# Nonlinear Coefficient Initial Values:
# =======================================================================================================================================================
#    Sigma:        prices      product_att1   product_att2   product_att3   |  Sigma Squared:     prices      product_att1   product_att2   product_att3
# ------------  -------------  -------------  -------------  -------------  |  --------------  -------------  -------------  -------------  -------------
#    prices     +1.000000E+00                                               |      prices      +1.000000E+00  +1.000000E+00  +1.000000E+00  +1.000000E+00
# product_att1  +1.000000E+00  +1.000000E+00                                |   product_att1   +1.000000E+00  +2.000000E+00  +2.000000E+00  +2.000000E+00
# product_att2  +1.000000E+00  +1.000000E+00  +1.000000E+00                 |   product_att2   +1.000000E+00  +2.000000E+00  +3.000000E+00  +3.000000E+00
# product_att3  +1.000000E+00  +1.000000E+00  +1.000000E+00  +1.000000E+00  |   product_att3   +1.000000E+00  +2.000000E+00  +3.000000E+00  +4.000000E+00
# =======================================================================================================================================================
# Starting optimization ...
#
# GMM   Optimization   Objective   Fixed Point  Contraction  Clipped    Objective      Objective      Gradient
# Step   Iterations   Evaluations  Iterations   Evaluations  Shares       Value       Improvement       Norm                                                                              Theta
# ----  ------------  -----------  -----------  -----------  -------  -------------  -------------  -------------  ----------------------------------------------------------------------------------------------------------------------------------------------------
#  1         0             1           826         2534         0     +3.182257E+02                 +1.947771E+02  +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+00, +1.000000E+
#  1         32           48           559         1723         0     +7.318146E-21                 +3.414550E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           49           558         1722         0     +7.318442E-21                 +3.393238E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           50           558         1719         0     +7.317331E-21                 +3.384846E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#
# GMM   Optimization   Objective   Fixed Point  Contraction  Clipped    Objective      Objective      Gradient
# Step   Iterations   Evaluations  Iterations   Evaluations  Shares       Value       Improvement       Norm                                                                              Theta
# ----  ------------  -----------  -----------  -----------  -------  -------------  -------------  -------------  ----------------------------------------------------------------------------------------------------------------------------------------------------
#  1         32           51           556         1721         0     +7.316699E-21                 +3.392801E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           52           560         1725         0     +7.407272E-21                 +3.080123E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           53           559         1724         0     +7.351893E-21                 +3.238903E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           54           559         1723         0     +7.330081E-21                 +3.293087E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           55           560         1726         0     +7.323210E-21                 +3.403881E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           56           558         1723         0     +7.318266E-21                 +3.344627E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           57           560         1723         0     +7.319631E-21                 +3.387893E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           58           559         1725         0     +7.319132E-21                 +3.398751E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           59           560         1724         0     +7.318044E-21                 +3.387369E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           60           559         1723         0     +7.319082E-21                 +3.391266E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           61           560         1724         0     +7.318586E-21                 +3.382174E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           62           561         1724         0     +7.315311E-21                 +3.396135E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  1         32           63           558         1719         0     +7.317331E-21                 +3.384846E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#
# The optimization routine failed to converge. This problem can sometimes be mitigated by choosing more reasonable initial parameter values, setting more conservative bounds, or configuring other optimization settings.
#
#
# Optimization failed after 00:04:22.
# Computing the Hessian and and updating the weighting matrix ...
# Computed results after 00:01:52.
#
# Problem Results Summary:
# =============================================================================================
# GMM     Objective      Gradient         Hessian         Hessian     Clipped  Weighting Matrix
# Step      Value          Norm       Min Eigenvalue  Max Eigenvalue  Shares   Condition Number
# ----  -------------  -------------  --------------  --------------  -------  ----------------
#  1    +7.316699E-21  +3.392801E-10  -1.158504E-03   +1.038379E+02      0      +8.157398E+01
# =============================================================================================
#
# Starting optimization ...
#
# GMM   Optimization   Objective   Fixed Point  Contraction  Clipped    Objective      Objective      Gradient
# Step   Iterations   Evaluations  Iterations   Evaluations  Shares       Value       Improvement       Norm                                                                              Theta
# ----  ------------  -----------  -----------  -----------  -------  -------------  -------------  -------------  ----------------------------------------------------------------------------------------------------------------------------------------------------
#  2         0             1            0           50          0     +3.394992E-21                 +2.819920E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  2         0             2           218          704         0     +2.111158E-18                 +8.623355E-09  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  2         0             3           165          534         0     +1.610078E-21  +1.784914E-21  +1.150096E-10  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#  2         1             4           185          593         0     +9.863134E-22  +6.237644E-22  +7.260811E-11  -5.959417E-01, -5.947330E-01, -8.584788E-01, +8.041997E-01, -6.294663E-01, +7.460448E-01, +2.027645E-01, +6.599980E-02, +3.741896E-01, +3.404977E-01
#
# Optimization completed after 00:00:09.
# Computing the Hessian and estimating standard errors ...
# Computed results after 00:01:04.
#
# Problem Results Summary:
# ================================================================================================================
# GMM     Objective      Gradient         Hessian         Hessian     Clipped  Weighting Matrix  Covariance Matrix
# Step      Value          Norm       Min Eigenvalue  Max Eigenvalue  Shares   Condition Number  Condition Number
# ----  -------------  -------------  --------------  --------------  -------  ----------------  -----------------
#  2    +9.863134E-22  +7.260811E-11  -3.834998E-04   +4.621128E+01      0      +9.315625E+01      +3.600824E+17
# ================================================================================================================
#
# Cumulative Statistics:
# ===========================================================================
# Computation  Optimizer  Optimization   Objective   Fixed Point  Contraction
#    Time      Converged   Iterations   Evaluations  Iterations   Evaluations
# -----------  ---------  ------------  -----------  -----------  -----------
#  00:07:26       No           34           69          37907       117041
# ===========================================================================
#
# Nonlinear Coefficient Estimates (Robust SEs in Parentheses):
# =======================================================================================================================================================================
#    Sigma:         prices        product_att1     product_att2     product_att3    |  Sigma Squared:      prices        product_att1     product_att2     product_att3
# ------------  ---------------  ---------------  ---------------  ---------------  |  --------------  ---------------  ---------------  ---------------  ---------------
#    prices      -5.959417E-01                                                      |      prices       +3.551465E-01    +3.544262E-01    -4.792561E-01    -1.208358E-01
#               (+7.350123E-01)                                                     |                  (+8.760489E-01)  (+4.752043E-01)  (+1.583413E+00)  (+1.129643E-01)
#                                                                                   |
# product_att1   -5.947330E-01    -8.584788E-01                                     |   product_att1    +3.544262E-01    +1.090693E+00    +6.209927E-02    -1.772502E-01
#               (+5.639613E-01)  (+2.833910E-01)                                    |                  (+4.752043E-01)  (+6.993695E-01)  (+4.315509E-01)  (+1.205704E+00)
#                                                                                   |
# product_att2   +8.041997E-01    -6.294663E-01    +7.460448E-01                    |   product_att2    -4.792561E-01    +6.209927E-02    +1.599548E+00    +4.006807E-01
#               (+1.686266E+00)  (+1.136742E+00)  (+2.706758E-01)                   |                  (+1.583413E+00)  (+4.315509E-01)  (+3.978559E+00)  (+1.198571E+00)
#                                                                                   |
# product_att3   +2.027645E-01    +6.599980E-02    +3.741896E-01    +3.404977E-01   |   product_att3    -1.208358E-01    -1.772502E-01    +4.006807E-01    +3.014260E-01
#               (+4.148486E-01)  (+1.724948E+00)  (+2.231554E-01)  (+7.608424E-01)  |                  (+1.129643E-01)  (+1.205704E+00)  (+1.198571E+00)  (+5.966601E-01)
# =======================================================================================================================================================================
#
# Beta Estimates (Robust SEs in Parentheses):
# ===================================================================================
#        1             prices        product_att1     product_att2     product_att3
# ---------------  ---------------  ---------------  ---------------  ---------------
#  +2.535396E+00    -1.933014E+00    +2.519166E+00    +1.446990E+00    +6.239143E-01
# (+1.724717E+00)  (+6.028551E-01)  (+5.411933E-01)  (+1.480843E+00)  (+7.258489E-01)
# ===================================================================================
# Problem Results Summary:
# ================================================================================================================
# GMM     Objective      Gradient         Hessian         Hessian     Clipped  Weighting Matrix  Covariance Matrix
# Step      Value          Norm       Min Eigenvalue  Max Eigenvalue  Shares   Condition Number  Condition Number
# ----  -------------  -------------  --------------  --------------  -------  ----------------  -----------------
#  2    +9.863134E-22  +7.260811E-11  -3.834998E-04   +4.621128E+01      0      +9.315625E+01      +3.600824E+17
# ================================================================================================================
#
# Cumulative Statistics:
# ===========================================================================
# Computation  Optimizer  Optimization   Objective   Fixed Point  Contraction
#    Time      Converged   Iterations   Evaluations  Iterations   Evaluations
# -----------  ---------  ------------  -----------  -----------  -----------
#  00:07:26       No           34           69          37907       117041
# ===========================================================================
#
# Nonlinear Coefficient Estimates (Robust SEs in Parentheses):
# =======================================================================================================================================================================
#    Sigma:         prices        product_att1     product_att2     product_att3    |  Sigma Squared:      prices        product_att1     product_att2     product_att3
# ------------  ---------------  ---------------  ---------------  ---------------  |  --------------  ---------------  ---------------  ---------------  ---------------
#    prices      -5.959417E-01                                                      |      prices       +3.551465E-01    +3.544262E-01    -4.792561E-01    -1.208358E-01
#               (+7.350123E-01)                                                     |                  (+8.760489E-01)  (+4.752043E-01)  (+1.583413E+00)  (+1.129643E-01)
#                                                                                   |
# product_att1   -5.947330E-01    -8.584788E-01                                     |   product_att1    +3.544262E-01    +1.090693E+00    +6.209927E-02    -1.772502E-01
#               (+5.639613E-01)  (+2.833910E-01)                                    |                  (+4.752043E-01)  (+6.993695E-01)  (+4.315509E-01)  (+1.205704E+00)
#                                                                                   |
# product_att2   +8.041997E-01    -6.294663E-01    +7.460448E-01                    |   product_att2    -4.792561E-01    +6.209927E-02    +1.599548E+00    +4.006807E-01
#               (+1.686266E+00)  (+1.136742E+00)  (+2.706758E-01)                   |                  (+1.583413E+00)  (+4.315509E-01)  (+3.978559E+00)  (+1.198571E+00)
#                                                                                   |
# product_att3   +2.027645E-01    +6.599980E-02    +3.741896E-01    +3.404977E-01   |   product_att3    -1.208358E-01    -1.772502E-01    +4.006807E-01    +3.014260E-01
#               (+4.148486E-01)  (+1.724948E+00)  (+2.231554E-01)  (+7.608424E-01)  |                  (+1.129643E-01)  (+1.205704E+00)  (+1.198571E+00)  (+5.966601E-01)
# =======================================================================================================================================================================
#
# Beta Estimates (Robust SEs in Parentheses):
# ===================================================================================
#        1             prices        product_att1     product_att2     product_att3
# ---------------  ---------------  ---------------  ---------------  ---------------
#  +2.535396E+00    -1.933014E+00    +2.519166E+00    +1.446990E+00    +6.239143E-01
# (+1.724717E+00)  (+6.028551E-01)  (+5.411933E-01)  (+1.480843E+00)  (+7.258489E-01)
# ===================================================================================
